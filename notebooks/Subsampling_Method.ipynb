# %% [markdown]
# ### Example code for generating subsampled BAMs for benchmarking analysis

# %%
import pandas as pd

# %%
supp_tables = "../data/Shukla.Levine.Gundem Supplementary Tables.xlsx"
sup8 = pd.read_excel(supp_tables, sheet_name=7, header=1)

# %%
samples = sup8[["Individual ID", "Original Coverage"]]

# %% [markdown]
# ### Calculated fractions for subsampling for all potential target coverages

# %%
to_subsample = pd.DataFrame(columns=["ID","Full Coverage","Target Coverage","Fraction"])
for _, sample in samples.iterrows():
    coverage = sample["Original Coverage"]
    for tc in [100, 80, 60, 30]:
        if coverage > tc + 5:
            to_subsample = to_subsample.append(
                {
                    "ID": sample["Individual ID"],
                    "Full Coverage": sample["Original Coverage"],
                    "Target Coverage": tc,
                    "Fraction": tc / sample["Original Coverage"],
                },
                ignore_index=True,
            )

# %%
to_subsample.head()
# Out:
#         ID Full Coverage Target Coverage  Fraction
# 0  H133673            98              80  0.816327
# 1  H133673            98              60  0.612245
# 2  H133673            98              30  0.306122
# 3  H134753           105              80  0.761905
# 4  H134753           105              60  0.571429

# %% [markdown]
# ### Code below is to demonstrate how BAMs were subsampled  to various levels. This was done on an HPC cluster using parallel jobs consisting of 4 tasks.

# %%
seed = '3423423'
for idx, row in to_subsample.iterrows():
    sid = row["ID"]
    target_cov = row["Target Coverage"]
    fraction = str(round(row["Fraction"], 4)).split(".")[1]
    
    # should be replaced with real bam path
    in_bam = f"{sid}.bam"
    out_bam = f"{sid}_{target_cov}X.bam"
    
    cmd = (
        f"samtools view -h -s {seed}.{fraction} -@4 {in_bam} -b > {out_bam}"
    )
    print(cmd)
# Out:
# samtools view -h -s 3423423.8163 -@4 H133673.bam -b > H133673_80X.bam
# samtools view -h -s 3423423.6122 -@4 H133673.bam -b > H133673_60X.bam
# samtools view -h -s 3423423.3061 -@4 H133673.bam -b > H133673_30X.bam
# samtools view -h -s 3423423.7619 -@4 H134753.bam -b > H134753_80X.bam
# samtools view -h -s 3423423.5714 -@4 H134753.bam -b > H134753_60X.bam
# samtools view -h -s 3423423.2857 -@4 H134753.bam -b > H134753_30X.bam
# samtools view -h -s 3423423.8955 -@4 H134754.bam -b > H134754_60X.bam
# samtools view -h -s 3423423.4478 -@4 H134754.bam -b > H134754_30X.bam
# samtools view -h -s 3423423.7407 -@4 H134755.bam -b > H134755_60X.bam
# samtools view -h -s 3423423.3704 -@4 H134755.bam -b > H134755_30X.bam
# samtools view -h -s 3423423.8791 -@4 H134756.bam -b > H134756_80X.bam
# samtools view -h -s 3423423.6593 -@4 H134756.bam -b > H134756_60X.bam
# samtools view -h -s 3423423.3297 -@4 H134756.bam -b > H134756_30X.bam
# samtools view -h -s 3423423.8451 -@4 H134757.bam -b > H134757_60X.bam
# samtools view -h -s 3423423.4225 -@4 H134757.bam -b > H134757_30X.bam
# samtools view -h -s 3423423.8955 -@4 H134202.bam -b > H134202_60X.bam
# samtools view -h -s 3423423.4478 -@4 H134202.bam -b > H134202_30X.bam
# samtools view -h -s 3423423.8772 -@4 H135022.bam -b > H135022_100X.bam
# samtools view -h -s 3423423.7018 -@4 H135022.bam -b > H135022_80X.bam
# samtools view -h -s 3423423.5263 -@4 H135022.bam -b > H135022_60X.bam
# samtools view -h -s 3423423.2632 -@4 H135022.bam -b > H135022_30X.bam
# samtools view -h -s 3423423.8696 -@4 H135062.bam -b > H135062_80X.bam
# samtools view -h -s 3423423.6522 -@4 H135062.bam -b > H135062_60X.bam
# samtools view -h -s 3423423.3261 -@4 H135062.bam -b > H135062_30X.bam
# samtools view -h -s 3423423.7792 -@4 H135066.bam -b > H135066_60X.bam
# samtools view -h -s 3423423.3896 -@4 H135066.bam -b > H135066_30X.bam
# samtools view -h -s 3423423.7692 -@4 H135073.bam -b > H135073_80X.bam
# samtools view -h -s 3423423.5769 -@4 H135073.bam -b > H135073_60X.bam
# samtools view -h -s 3423423.2885 -@4 H135073.bam -b > H135073_30X.bam
# samtools view -h -s 3423423.7407 -@4 H135074.bam -b > H135074_60X.bam
# samtools view -h -s 3423423.3704 -@4 H135074.bam -b > H135074_30X.bam
# samtools view -h -s 3423423.9195 -@4 H135076.bam -b > H135076_80X.bam
# samtools view -h -s 3423423.6897 -@4 H135076.bam -b > H135076_60X.bam
# samtools view -h -s 3423423.3448 -@4 H135076.bam -b > H135076_30X.bam
# samtools view -h -s 3423423.8696 -@4 H133676.bam -b > H133676_60X.bam
# samtools view -h -s 3423423.4348 -@4 H133676.bam -b > H133676_30X.bam
# samtools view -h -s 3423423.7767 -@4 H134769.bam -b > H134769_80X.bam
# samtools view -h -s 3423423.5825 -@4 H134769.bam -b > H134769_60X.bam
# samtools view -h -s 3423423.2913 -@4 H134769.bam -b > H134769_30X.bam
# samtools view -h -s 3423423.8163 -@4 H135387.bam -b > H135387_80X.bam
# samtools view -h -s 3423423.6122 -@4 H135387.bam -b > H135387_60X.bam
# samtools view -h -s 3423423.3061 -@4 H135387.bam -b > H135387_30X.bam
# samtools view -h -s 3423423.7407 -@4 H135393.bam -b > H135393_60X.bam
# samtools view -h -s 3423423.3704 -@4 H135393.bam -b > H135393_30X.bam
# samtools view -h -s 3423423.6711 -@4 H135421.bam -b > H135421_100X.bam
# samtools view -h -s 3423423.5369 -@4 H135421.bam -b > H135421_80X.bam
# samtools view -h -s 3423423.4027 -@4 H135421.bam -b > H135421_60X.bam
# samtools view -h -s 3423423.2013 -@4 H135421.bam -b > H135421_30X.bam
# samtools view -h -s 3423423.7895 -@4 H135463.bam -b > H135463_60X.bam
# samtools view -h -s 3423423.3947 -@4 H135463.bam -b > H135463_30X.bam
# samtools view -h -s 3423423.7874 -@4 H135420.bam -b > H135420_100X.bam
# samtools view -h -s 3423423.6299 -@4 H135420.bam -b > H135420_80X.bam
# samtools view -h -s 3423423.4724 -@4 H135420.bam -b > H135420_60X.bam
# samtools view -h -s 3423423.2362 -@4 H135420.bam -b > H135420_30X.bam
# samtools view -h -s 3423423.8696 -@4 H134733.bam -b > H134733_60X.bam
# samtools view -h -s 3423423.4348 -@4 H134733.bam -b > H134733_30X.bam
# samtools view -h -s 3423423.9009 -@4 H135467.bam -b > H135467_100X.bam
# samtools view -h -s 3423423.7207 -@4 H135467.bam -b > H135467_80X.bam
# samtools view -h -s 3423423.5405 -@4 H135467.bam -b > H135467_60X.bam
# samtools view -h -s 3423423.2703 -@4 H135467.bam -b > H135467_30X.bam
# samtools view -h -s 3423423.8772 -@4 H108333.bam -b > H108333_100X.bam
# samtools view -h -s 3423423.7018 -@4 H108333.bam -b > H108333_80X.bam
# samtools view -h -s 3423423.5263 -@4 H108333.bam -b > H108333_60X.bam
# samtools view -h -s 3423423.2632 -@4 H108333.bam -b > H108333_30X.bam
# samtools view -h -s 3423423.8889 -@4 H135459.bam -b > H135459_80X.bam
# samtools view -h -s 3423423.6667 -@4 H135459.bam -b > H135459_60X.bam
# samtools view -h -s 3423423.3333 -@4 H135459.bam -b > H135459_30X.bam
# samtools view -h -s 3423423.7767 -@4 H135466.bam -b > H135466_80X.bam
# samtools view -h -s 3423423.5825 -@4 H135466.bam -b > H135466_60X.bam
# samtools view -h -s 3423423.2913 -@4 H135466.bam -b > H135466_30X.bam
# samtools view -h -s 3423423.9434 -@4 H135973.bam -b > H135973_100X.bam
# samtools view -h -s 3423423.7547 -@4 H135973.bam -b > H135973_80X.bam
# samtools view -h -s 3423423.566 -@4 H135973.bam -b > H135973_60X.bam
# samtools view -h -s 3423423.283 -@4 H135973.bam -b > H135973_30X.bam
# samtools view -h -s 3423423.8791 -@4 H135963.bam -b > H135963_80X.bam
# samtools view -h -s 3423423.6593 -@4 H135963.bam -b > H135963_60X.bam
# samtools view -h -s 3423423.3297 -@4 H135963.bam -b > H135963_30X.bam
# samtools view -h -s 3423423.8081 -@4 H135967.bam -b > H135967_80X.bam
# samtools view -h -s 3423423.6061 -@4 H135967.bam -b > H135967_60X.bam
# samtools view -h -s 3423423.303 -@4 H135967.bam -b > H135967_30X.bam
# samtools view -h -s 3423423.885 -@4 H135988.bam -b > H135988_100X.bam
# samtools view -h -s 3423423.708 -@4 H135988.bam -b > H135988_80X.bam
# samtools view -h -s 3423423.531 -@4 H135988.bam -b > H135988_60X.bam
# samtools view -h -s 3423423.2655 -@4 H135988.bam -b > H135988_30X.bam
# samtools view -h -s 3423423.9259 -@4 H135990.bam -b > H135990_100X.bam
# samtools view -h -s 3423423.7407 -@4 H135990.bam -b > H135990_80X.bam
# samtools view -h -s 3423423.5556 -@4 H135990.bam -b > H135990_60X.bam
# samtools view -h -s 3423423.2778 -@4 H135990.bam -b > H135990_30X.bam
# samtools view -h -s 3423423.7692 -@4 H136062.bam -b > H136062_60X.bam
# samtools view -h -s 3423423.3846 -@4 H136062.bam -b > H136062_30X.bam
# samtools view -h -s 3423423.8081 -@4 H136134.bam -b > H136134_80X.bam
# samtools view -h -s 3423423.6061 -@4 H136134.bam -b > H136134_60X.bam
# samtools view -h -s 3423423.303 -@4 H136134.bam -b > H136134_30X.bam
# samtools view -h -s 3423423.7812 -@4 H136136.bam -b > H136136_100X.bam
# samtools view -h -s 3423423.625 -@4 H136136.bam -b > H136136_80X.bam
# samtools view -h -s 3423423.4688 -@4 H136136.bam -b > H136136_60X.bam
# samtools view -h -s 3423423.2344 -@4 H136136.bam -b > H136136_30X.bam
# samtools view -h -s 3423423.9259 -@4 H135089.bam -b > H135089_100X.bam
# samtools view -h -s 3423423.7407 -@4 H135089.bam -b > H135089_80X.bam
# samtools view -h -s 3423423.5556 -@4 H135089.bam -b > H135089_60X.bam
# samtools view -h -s 3423423.2778 -@4 H135089.bam -b > H135089_30X.bam
# samtools view -h -s 3423423.8511 -@4 H136083.bam -b > H136083_80X.bam
# samtools view -h -s 3423423.6383 -@4 H136083.bam -b > H136083_60X.bam
# samtools view -h -s 3423423.3191 -@4 H136083.bam -b > H136083_30X.bam
# samtools view -h -s 3423423.7407 -@4 H136139.bam -b > H136139_60X.bam
# samtools view -h -s 3423423.3704 -@4 H136139.bam -b > H136139_30X.bam
# samtools view -h -s 3423423.8163 -@4 H136375.bam -b > H136375_80X.bam
# samtools view -h -s 3423423.6122 -@4 H136375.bam -b > H136375_60X.bam
# samtools view -h -s 3423423.3061 -@4 H136375.bam -b > H136375_30X.bam
# samtools view -h -s 3423423.7519 -@4 H136424.bam -b > H136424_100X.bam
# samtools view -h -s 3423423.6015 -@4 H136424.bam -b > H136424_80X.bam
# samtools view -h -s 3423423.4511 -@4 H136424.bam -b > H136424_60X.bam
# samtools view -h -s 3423423.2256 -@4 H136424.bam -b > H136424_30X.bam
# samtools view -h -s 3423423.8547 -@4 H136425.bam -b > H136425_100X.bam
# samtools view -h -s 3423423.6838 -@4 H136425.bam -b > H136425_80X.bam
# samtools view -h -s 3423423.5128 -@4 H136425.bam -b > H136425_60X.bam
# samtools view -h -s 3423423.2564 -@4 H136425.bam -b > H136425_30X.bam
# samtools view -h -s 3423423.8772 -@4 H136428.bam -b > H136428_100X.bam
# samtools view -h -s 3423423.7018 -@4 H136428.bam -b > H136428_80X.bam
# samtools view -h -s 3423423.5263 -@4 H136428.bam -b > H136428_60X.bam
# samtools view -h -s 3423423.2632 -@4 H136428.bam -b > H136428_30X.bam
# samtools view -h -s 3423423.8989 -@4 H135088.bam -b > H135088_80X.bam
# samtools view -h -s 3423423.6742 -@4 H135088.bam -b > H135088_60X.bam
# samtools view -h -s 3423423.3371 -@4 H135088.bam -b > H135088_30X.bam
# samtools view -h -s 3423423.7921 -@4 H133672.bam -b > H133672_80X.bam
# samtools view -h -s 3423423.5941 -@4 H133672.bam -b > H133672_60X.bam
# samtools view -h -s 3423423.297 -@4 H133672.bam -b > H133672_30X.bam
# samtools view -h -s 3423423.8696 -@4 H133671.bam -b > H133671_80X.bam
# samtools view -h -s 3423423.6522 -@4 H133671.bam -b > H133671_60X.bam
# samtools view -h -s 3423423.3261 -@4 H133671.bam -b > H133671_30X.bam
# samtools view -h -s 3423423.6944 -@4 H133675.bam -b > H133675_100X.bam
# samtools view -h -s 3423423.5556 -@4 H133675.bam -b > H133675_80X.bam
# samtools view -h -s 3423423.4167 -@4 H133675.bam -b > H133675_60X.bam
# samtools view -h -s 3423423.2083 -@4 H133675.bam -b > H133675_30X.bam
# samtools view -h -s 3423423.8421 -@4 H133674.bam -b > H133674_80X.bam
# samtools view -h -s 3423423.6316 -@4 H133674.bam -b > H133674_60X.bam
# samtools view -h -s 3423423.3158 -@4 H133674.bam -b > H133674_30X.bam
# samtools view -h -s 3423423.7317 -@4 H136631.bam -b > H136631_60X.bam
# samtools view -h -s 3423423.3659 -@4 H136631.bam -b > H136631_30X.bam
# samtools view -h -s 3423423.885 -@4 H136632.bam -b > H136632_100X.bam
# samtools view -h -s 3423423.708 -@4 H136632.bam -b > H136632_80X.bam
# samtools view -h -s 3423423.531 -@4 H136632.bam -b > H136632_60X.bam
# samtools view -h -s 3423423.2655 -@4 H136632.bam -b > H136632_30X.bam
# samtools view -h -s 3423423.9346 -@4 H136633.bam -b > H136633_100X.bam
# samtools view -h -s 3423423.7477 -@4 H136633.bam -b > H136633_80X.bam
# samtools view -h -s 3423423.5607 -@4 H136633.bam -b > H136633_60X.bam
# samtools view -h -s 3423423.2804 -@4 H136633.bam -b > H136633_30X.bam
# samtools view -h -s 3423423.7229 -@4 H136640.bam -b > H136640_60X.bam
# samtools view -h -s 3423423.3614 -@4 H136640.bam -b > H136640_30X.bam
# samtools view -h -s 3423423.9302 -@4 H136641.bam -b > H136641_80X.bam
# samtools view -h -s 3423423.6977 -@4 H136641.bam -b > H136641_60X.bam
# samtools view -h -s 3423423.3488 -@4 H136641.bam -b > H136641_30X.bam
# samtools view -h -s 3423423.5525 -@4 H136648.bam -b > H136648_100X.bam
# samtools view -h -s 3423423.442 -@4 H136648.bam -b > H136648_80X.bam
# samtools view -h -s 3423423.3315 -@4 H136648.bam -b > H136648_60X.bam
# samtools view -h -s 3423423.1657 -@4 H136648.bam -b > H136648_30X.bam
# samtools view -h -s 3423423.8421 -@4 H156407.bam -b > H156407_80X.bam
# samtools view -h -s 3423423.6316 -@4 H156407.bam -b > H156407_60X.bam
# samtools view -h -s 3423423.3158 -@4 H156407.bam -b > H156407_30X.bam
# samtools view -h -s 3423423.75 -@4 H156409.bam -b > H156409_60X.bam
# samtools view -h -s 3423423.375 -@4 H156409.bam -b > H156409_30X.bam
# samtools view -h -s 3423423.8602 -@4 H156416.bam -b > H156416_80X.bam
# samtools view -h -s 3423423.6452 -@4 H156416.bam -b > H156416_60X.bam
# samtools view -h -s 3423423.3226 -@4 H156416.bam -b > H156416_30X.bam
# samtools view -h -s 3423423.7317 -@4 H136433.bam -b > H136433_60X.bam
# samtools view -h -s 3423423.3659 -@4 H136433.bam -b > H136433_30X.bam
# samtools view -h -s 3423423.9434 -@4 H156418.bam -b > H156418_100X.bam
# samtools view -h -s 3423423.7547 -@4 H156418.bam -b > H156418_80X.bam
# samtools view -h -s 3423423.566 -@4 H156418.bam -b > H156418_60X.bam
# samtools view -h -s 3423423.283 -@4 H156418.bam -b > H156418_30X.bam
# samtools view -h -s 3423423.7895 -@4 H158151.bam -b > H158151_60X.bam
# samtools view -h -s 3423423.3947 -@4 H158151.bam -b > H158151_30X.bam
# samtools view -h -s 3423423.8791 -@4 H158180.bam -b > H158180_80X.bam
# samtools view -h -s 3423423.6593 -@4 H158180.bam -b > H158180_60X.bam
# samtools view -h -s 3423423.3297 -@4 H158180.bam -b > H158180_30X.bam
# samtools view -h -s 3423423.8081 -@4 H158181.bam -b > H158181_80X.bam
# samtools view -h -s 3423423.6061 -@4 H158181.bam -b > H158181_60X.bam
# samtools view -h -s 3423423.303 -@4 H158181.bam -b > H158181_30X.bam
# samtools view -h -s 3423423.6452 -@4 H158182.bam -b > H158182_100X.bam
# samtools view -h -s 3423423.5161 -@4 H158182.bam -b > H158182_80X.bam
# samtools view -h -s 3423423.3871 -@4 H158182.bam -b > H158182_60X.bam
# samtools view -h -s 3423423.1935 -@4 H158182.bam -b > H158182_30X.bam
# samtools view -h -s 3423423.7059 -@4 H158183.bam -b > H158183_60X.bam
# samtools view -h -s 3423423.3529 -@4 H158183.bam -b > H158183_30X.bam
# samtools view -h -s 3423423.8696 -@4 H158184.bam -b > H158184_80X.bam
# samtools view -h -s 3423423.6522 -@4 H158184.bam -b > H158184_60X.bam
# samtools view -h -s 3423423.3261 -@4 H158184.bam -b > H158184_30X.bam
# samtools view -h -s 3423423.9302 -@4 H158223.bam -b > H158223_80X.bam
# samtools view -h -s 3423423.6977 -@4 H158223.bam -b > H158223_60X.bam
# samtools view -h -s 3423423.3488 -@4 H158223.bam -b > H158223_30X.bam
# samtools view -h -s 3423423.9091 -@4 H158271.bam -b > H158271_100X.bam
# samtools view -h -s 3423423.7273 -@4 H158271.bam -b > H158271_80X.bam
# samtools view -h -s 3423423.5455 -@4 H158271.bam -b > H158271_60X.bam
# samtools view -h -s 3423423.2727 -@4 H158271.bam -b > H158271_30X.bam
# samtools view -h -s 3423423.8547 -@4 H158273.bam -b > H158273_100X.bam
# samtools view -h -s 3423423.6838 -@4 H158273.bam -b > H158273_80X.bam
# samtools view -h -s 3423423.5128 -@4 H158273.bam -b > H158273_60X.bam
# samtools view -h -s 3423423.2564 -@4 H158273.bam -b > H158273_30X.bam
# samtools view -h -s 3423423.7792 -@4 H134768.bam -b > H134768_60X.bam
# samtools view -h -s 3423423.3896 -@4 H134768.bam -b > H134768_30X.bam
# samtools view -h -s 3423423.8989 -@4 H158493.bam -b > H158493_80X.bam
# samtools view -h -s 3423423.6742 -@4 H158493.bam -b > H158493_60X.bam
# samtools view -h -s 3423423.3371 -@4 H158493.bam -b > H158493_30X.bam
# samtools view -h -s 3423423.8791 -@4 H134738.bam -b > H134738_80X.bam
# samtools view -h -s 3423423.6593 -@4 H134738.bam -b > H134738_60X.bam
# samtools view -h -s 3423423.3297 -@4 H134738.bam -b > H134738_30X.bam
# samtools view -h -s 3423423.8421 -@4 H158878.bam -b > H158878_80X.bam
# samtools view -h -s 3423423.6316 -@4 H158878.bam -b > H158878_60X.bam
# samtools view -h -s 3423423.3158 -@4 H158878.bam -b > H158878_30X.bam
# samtools view -h -s 3423423.8696 -@4 H158880.bam -b > H158880_100X.bam
# samtools view -h -s 3423423.6957 -@4 H158880.bam -b > H158880_80X.bam
# samtools view -h -s 3423423.5217 -@4 H158880.bam -b > H158880_60X.bam
# samtools view -h -s 3423423.2609 -@4 H158880.bam -b > H158880_30X.bam
# samtools view -h -s 3423423.7143 -@4 H158916.bam -b > H158916_60X.bam
# samtools view -h -s 3423423.3571 -@4 H158916.bam -b > H158916_30X.bam
# samtools view -h -s 3423423.7921 -@4 H158917.bam -b > H158917_80X.bam
# samtools view -h -s 3423423.5941 -@4 H158917.bam -b > H158917_60X.bam
# samtools view -h -s 3423423.297 -@4 H158917.bam -b > H158917_30X.bam
# samtools view -h -s 3423423.9091 -@4 H158918.bam -b > H158918_80X.bam
# samtools view -h -s 3423423.6818 -@4 H158918.bam -b > H158918_60X.bam
# samtools view -h -s 3423423.3409 -@4 H158918.bam -b > H158918_30X.bam
# samtools view -h -s 3423423.6849 -@4 H158919.bam -b > H158919_100X.bam
# samtools view -h -s 3423423.5479 -@4 H158919.bam -b > H158919_80X.bam
# samtools view -h -s 3423423.411 -@4 H158919.bam -b > H158919_60X.bam
# samtools view -h -s 3423423.2055 -@4 H158919.bam -b > H158919_30X.bam
# samtools view -h -s 3423423.9346 -@4 H159103.bam -b > H159103_100X.bam
# samtools view -h -s 3423423.7477 -@4 H159103.bam -b > H159103_80X.bam
# samtools view -h -s 3423423.5607 -@4 H159103.bam -b > H159103_60X.bam
# samtools view -h -s 3423423.2804 -@4 H159103.bam -b > H159103_30X.bam
# samtools view -h -s 3423423.7692 -@4 H159153.bam -b > H159153_100X.bam
# samtools view -h -s 3423423.6154 -@4 H159153.bam -b > H159153_80X.bam
# samtools view -h -s 3423423.4615 -@4 H159153.bam -b > H159153_60X.bam
# samtools view -h -s 3423423.2308 -@4 H159153.bam -b > H159153_30X.bam
# samtools view -h -s 3423423.9174 -@4 H159369.bam -b > H159369_100X.bam
# samtools view -h -s 3423423.7339 -@4 H159369.bam -b > H159369_80X.bam
# samtools view -h -s 3423423.5505 -@4 H159369.bam -b > H159369_60X.bam
# samtools view -h -s 3423423.2752 -@4 H159369.bam -b > H159369_30X.bam
# samtools view -h -s 3423423.9302 -@4 H159370.bam -b > H159370_80X.bam
# samtools view -h -s 3423423.6977 -@4 H159370.bam -b > H159370_60X.bam
# samtools view -h -s 3423423.3488 -@4 H159370.bam -b > H159370_30X.bam
# samtools view -h -s 3423423.7843 -@4 H159371.bam -b > H159371_80X.bam
# samtools view -h -s 3423423.5882 -@4 H159371.bam -b > H159371_60X.bam
# samtools view -h -s 3423423.2941 -@4 H159371.bam -b > H159371_30X.bam
# samtools view -h -s 3423423.8197 -@4 H159446.bam -b > H159446_100X.bam
# samtools view -h -s 3423423.6557 -@4 H159446.bam -b > H159446_80X.bam
# samtools view -h -s 3423423.4918 -@4 H159446.bam -b > H159446_60X.bam
# samtools view -h -s 3423423.2459 -@4 H159446.bam -b > H159446_30X.bam
# samtools view -h -s 3423423.8791 -@4 H195916.bam -b > H195916_80X.bam
# samtools view -h -s 3423423.6593 -@4 H195916.bam -b > H195916_60X.bam
# samtools view -h -s 3423423.3297 -@4 H195916.bam -b > H195916_30X.bam
# samtools view -h -s 3423423.8602 -@4 H195918.bam -b > H195918_80X.bam
# samtools view -h -s 3423423.6452 -@4 H195918.bam -b > H195918_60X.bam
# samtools view -h -s 3423423.3226 -@4 H195918.bam -b > H195918_30X.bam
# samtools view -h -s 3423423.8791 -@4 H195921.bam -b > H195921_80X.bam
# samtools view -h -s 3423423.6593 -@4 H195921.bam -b > H195921_60X.bam
# samtools view -h -s 3423423.3297 -@4 H195921.bam -b > H195921_30X.bam
# samtools view -h -s 3423423.8791 -@4 H195922.bam -b > H195922_80X.bam
# samtools view -h -s 3423423.6593 -@4 H195922.bam -b > H195922_60X.bam
# samtools view -h -s 3423423.3297 -@4 H195922.bam -b > H195922_30X.bam
# samtools view -h -s 3423423.8108 -@4 H195923.bam -b > H195923_60X.bam
# samtools view -h -s 3423423.4054 -@4 H195923.bam -b > H195923_30X.bam
# samtools view -h -s 3423423.7042 -@4 H135462.bam -b > H135462_100X.bam
# samtools view -h -s 3423423.5634 -@4 H135462.bam -b > H135462_80X.bam
# samtools view -h -s 3423423.4225 -@4 H135462.bam -b > H135462_60X.bam
# samtools view -h -s 3423423.2113 -@4 H135462.bam -b > H135462_30X.bam
# samtools view -h -s 3423423.5848 -@4 H195989.bam -b > H195989_100X.bam
# samtools view -h -s 3423423.4678 -@4 H195989.bam -b > H195989_80X.bam
# samtools view -h -s 3423423.3509 -@4 H195989.bam -b > H195989_60X.bam
# samtools view -h -s 3423423.1754 -@4 H195989.bam -b > H195989_30X.bam
# samtools view -h -s 3423423.7229 -@4 H195990.bam -b > H195990_60X.bam
# samtools view -h -s 3423423.3614 -@4 H195990.bam -b > H195990_30X.bam
# samtools view -h -s 3423423.7595 -@4 H195991.bam -b > H195991_60X.bam
# samtools view -h -s 3423423.3797 -@4 H195991.bam -b > H195991_30X.bam
# samtools view -h -s 3423423.8511 -@4 H195992.bam -b > H195992_80X.bam
# samtools view -h -s 3423423.6383 -@4 H195992.bam -b > H195992_60X.bam
# samtools view -h -s 3423423.3191 -@4 H195992.bam -b > H195992_30X.bam
# samtools view -h -s 3423423.7407 -@4 H196046.bam -b > H196046_60X.bam
# samtools view -h -s 3423423.3704 -@4 H196046.bam -b > H196046_30X.bam
# samtools view -h -s 3423423.8889 -@4 H196094.bam -b > H196094_80X.bam
# samtools view -h -s 3423423.6667 -@4 H196094.bam -b > H196094_60X.bam
# samtools view -h -s 3423423.3333 -@4 H196094.bam -b > H196094_30X.bam
# samtools view -h -s 3423423.8602 -@4 H196095.bam -b > H196095_80X.bam
# samtools view -h -s 3423423.6452 -@4 H196095.bam -b > H196095_60X.bam
# samtools view -h -s 3423423.3226 -@4 H196095.bam -b > H196095_30X.bam
# samtools view -h -s 3423423.7692 -@4 H196227.bam -b > H196227_60X.bam
# samtools view -h -s 3423423.3846 -@4 H196227.bam -b > H196227_30X.bam
# samtools view -h -s 3423423.7576 -@4 H196231.bam -b > H196231_100X.bam
# samtools view -h -s 3423423.6061 -@4 H196231.bam -b > H196231_80X.bam
# samtools view -h -s 3423423.4545 -@4 H196231.bam -b > H196231_60X.bam
# samtools view -h -s 3423423.2273 -@4 H196231.bam -b > H196231_30X.bam
# samtools view -h -s 3423423.8197 -@4 H196232.bam -b > H196232_100X.bam
# samtools view -h -s 3423423.6557 -@4 H196232.bam -b > H196232_80X.bam
# samtools view -h -s 3423423.4918 -@4 H196232.bam -b > H196232_60X.bam
# samtools view -h -s 3423423.2459 -@4 H196232.bam -b > H196232_30X.bam
# samtools view -h -s 3423423.6944 -@4 H195920.bam -b > H195920_100X.bam
# samtools view -h -s 3423423.5556 -@4 H195920.bam -b > H195920_80X.bam
# samtools view -h -s 3423423.4167 -@4 H195920.bam -b > H195920_60X.bam
# samtools view -h -s 3423423.2083 -@4 H195920.bam -b > H195920_30X.bam
